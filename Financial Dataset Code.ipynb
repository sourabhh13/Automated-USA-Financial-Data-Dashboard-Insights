# %% [markdown]
# IMPORT ALL THE LIBRARIES

# %%
from google.oauth2 import service_account
from googleapiclient.discovery import build
import pandas as pd
import requests
from io import StringIO
from io import BytesIO  # For handling Excel files

# %% [markdown]
# SET THE PATH FOR  YOUR DOOR AND SCOPE

# %%
# Replace with the path to your service account credentials
SERVICE_ACCOUNT_FILE = "/content/drive-bridge-financial-data-e21f827ecd9b.json"
SCOPES = ['https://www.googleapis.com/auth/drive.readonly']


#service account file , tell the code where is the door address and what are the permission to open that door
#scope script defines the level of access (permissions) that your script is requesting from the Google API.  (Here the scope is read only.)

# %% [markdown]
# AUTHETICATE AND CREATE THE SERVICES

# %%
# Authenticate and create the service

credentials = service_account.Credentials.from_service_account_file(
    SERVICE_ACCOUNT_FILE, scopes=SCOPES)  #from the service account file we are using a function credentials.from_service_account_file
#It reads the service account file and authenticates our script using the permissions (scopes) defined.


service = build('drive', 'v3', credentials=credentials)
#This line builds the Google Drive API service, allowing your script to interact with Google Drive. Here's what it does
#build() is a function provided by the googleapiclient.discovery module that initializes the API service
#The first argument, 'drive', specifies the Google Drive API you want to use.

# %% [markdown]
# FOLDER ID

# %%
# Replace with your Google Drive folder ID
FOLDER_ID = '15UYA2eHZpuVPtGsmmJ0b5g4UGEXjRZaG'

# %% [markdown]
# FUNCTION TO LIST ALL THE FILES IN GOOGLE DRIVE

# %%
def list_files(service, folder_id):
    results = service.files().list(
        q=f"'{folder_id}' in parents",
        fields="files(id, name, mimeType)"
    ).execute()
    return results.get('files', [])

# %%
# Fetch the files
files = list_files(service, FOLDER_ID)
files
# Out:
# [{'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '1U-X2ss_mhQMQZBTiEynYwckujN-JKA7VBVxqGoTV2mI',
#   'name': 'combined_part_25'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '1TT2UOPw92KfNj-JRBzR4JGmoyXCaEo36L_-A6kcePPA',
#   'name': 'combined_part_24'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '1BkCewWqrJF5qJPE1WoyWpwHbr25KnGm_p5CGzAl8k1Y',
#   'name': 'combined_part_22'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '1NN-2B3ZxanZuYf-U3DfRSO3b9MMH3pbE3G3GNR92zKg',
#   'name': 'combined_part_23'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '1Qh9SrYHRzYVW1n6mlFlOo-S3FoB3WBCYQPLeWpMAOlY',
#   'name': 'combined_part_21'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '1dFcuDgduCTDXtWPkM6k0MOzSPMQlWmwwWPuxz2EpOWY',
#   'name': 'combined_part_20'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '1TXu88S7c9-0C-pZmXkUEFFTldssX8RgpmE3Yvar1WqQ',
#   'name': 'combined_part_19'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '1ECSsIJX7upJPU7Hmo3l5uS5qFJqXoBVxqxlH0ytYHhM',
#   'name': 'combined_part_18'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '1EREksNxLr7X61k79rPEUFszkVl8IhLjpVuIFxPdvfRg',
#   'name': 'combined_part_17'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '1GPprh2_PSxqbh7DSc6sChGVNKB8ByPfkpDdMDSsIr_s',
#   'name': 'combined_part_14'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '1r4XsJhycWE62SuEAv6UkjC9ZXJH2C34hZESmrtZZmvU',
#   'name': 'combined_part_13'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '1HQeNWwUDOKSJRuWF4V5Qz5H-gDxZ4IbXHLIIyy_81F0',
#   'name': 'combined_part_15'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '1VILVQYkROiF3Jjrp-hcsVMYJcDFbHGOBBbEuwjeHIRc',
#   'name': 'combined_part_16'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '1pGYLwKzh3dqsOMpPrrHlTKWAQW7yoqGd3d1QniFiiFs',
#   'name': 'combined_part_12'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '1FovcLg58Q9ntwDBMKA_uq4lUCfipYIFC3yJ3WECNlak',
#   'name': 'combined_part_11'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '1REMUp5rcQ7vzK4yGqcYD_dw8lEpmBjmbPY-0pwJbaMc',
#   'name': 'combined_part_5'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '1f0WiqI5NhjNDk9b7Zq99cDres44gxwmSx57-WRkxejc',
#   'name': 'combined_part_10'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '1jzLVRfa5T5SdXI5DCZgrvln3Yut6oj3vmTWTzesJQBA',
#   'name': 'combined_part_6'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '1HaeDf5XycTVhuF0E0ScIG48kcNqIJd-Z-n1A_7dLqdk',
#   'name': 'combined_part_2'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '1PT63AWw1LhmyhTxulJVZFRj2WNQavb4RPLnmJOJIwEk',
#   'name': 'combined_part_9'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '1rTDT1kTN-iCRa3QIZ30IA3YddLDAodEx-tY9CN7J8f0',
#   'name': 'combined_part_3'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '19oeHASuXq3W2M4reZrru83l_eJWm0sFfMxw_rODpnb4',
#   'name': 'combined_part_7'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '1Y5SQw6A7U3EUB3yVUkctseN-dkRehGO7vdRdg4Bk7kY',
#   'name': 'combined_part_4'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '15gDcMltH3wvS7iz9aMTFpqDJNp-9GX41bNBgVyxAADo',
#   'name': 'combined_part_8'},
#  {'mimeType': 'application/vnd.google-apps.spreadsheet',
#   'id': '1tKMRKGB3zGzpF0yPtTMECtceLrta17fNDPyW3RVH8Ek',
#   'name': 'combined_part_1'}]

# %%
# List to store dataframes for file content
file_dataframes = []

for file in files:
    file_id = file['id']
    file_name = file['name']
    mime_type = file['mimeType']

    # Check if the file is Google Sheets, CSV, or Excel
    if mime_type == 'application/vnd.google-apps.spreadsheet':
        # Export Google Sheets as CSV
        download_url = f"https://docs.google.com/spreadsheets/d/{file_id}/export?format=csv"
    elif mime_type == 'text/csv':
        # If it's already a CSV file
        download_url = f"https://drive.google.com/uc?export=download&id={file_id}"
    elif mime_type == 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet':
        # If it's an Excel file
        download_url = f"https://drive.google.com/uc?export=download&id={file_id}"
    else:
        continue  # Skip files that are not CSV, Google Sheets, or Excel


    response = requests.get(download_url)# Download and read the CSV or Excel file into a pandas dataframe
    if response.status_code == 200:  #status code 200 means files was successfully downonloaded
        if mime_type == 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet':
            # For Excel, use BytesIO to read the binary content
            df = pd.read_excel(BytesIO(response.content))
        else:
            # For CSV and Google Sheets (converted to CSV)
            df = pd.read_csv(StringIO(response.content.decode('utf-8')))
        file_dataframes.append(df)
    else:
        print(f"Error downloading file: {file_name}")

# %%
file_dataframes
# Out:
# [           ID Customer_ID     Month            Name   Age          SSN  \
#  0     0x23cca  CUS_0x8b6d   January  Scott Haggettl    23  796-69-6764
#  1     0x23ccb  CUS_0x8b6d  February  Scott Haggettl    23    #F%$D@*&8
#  2     0x23ccc  CUS_0x8b6d     March  Scott Haggettl    23  796-69-6764
#  3     0x23ccd  CUS_0x8b6d     April  Scott Haggettl  5615  796-69-6764
#  4     0x23cce  CUS_0x8b6d       May  Scott Haggettl    23  796-69-6764
#  ...       ...         ...       ...             ...   ...          ...
#  5995  0x25fe9  CUS_0x942c     April           Nicks    25  078-73-5990
#  5996  0x25fea  CUS_0x942c       May           Nicks    25  078-73-5990
#  5997  0x25feb  CUS_0x942c      June           Nicks    25  078-73-5990
#  5998  0x25fec  CUS_0x942c      July           Nicks    25  078-73-5990
#  5999  0x25fed  CUS_0x942c    August           Nicks    25  078-73-5990
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
#  0      Musician      102594.9            8391.575000                  3  ...
#  1      Musician     102594.9_            8391.575000                  3  ...
#  2      Musician      102594.9            8391.575000                  3  ...
#  3       _______      102594.9            8391.575000                  3  ...
#  4      Musician      102594.9                    NaN                  3  ...
#  ...         ...           ...                    ...                ...  ...
#  5995   Mechanic      39628.99            3359.415833                  4  ...
#  5996   Mechanic      39628.99            3359.415833                  4  ...
#  5997   Mechanic      39628.99            3359.415833                  4  ...
#  5998   Mechanic      39628.99            3359.415833                  4  ...
#  5999   Mechanic     39628.99_            3359.415833                  4  ...
#
#        Credit_Mix  Outstanding_Debt Credit_Utilization_Ratio  \
#  0       Standard            416.11                30.601881
#  1              _            416.11                43.528168
#  2       Standard            416.11                37.487060
#  3       Standard            416.11                35.125945
#  4       Standard            416.11                38.284492
#  ...          ...               ...                      ...
#  5995           _            502.38                34.663572
#  5996           _            502.38                40.565631
#  5997        Good            502.38                41.255522
#  5998        Good            502.38                33.638208
#  5999        Good            502.38                34.192463
#
#            Credit_History_Age  Payment_of_Min_Amount Total_EMI_per_month  \
#  0                        NaN                     No            0.000000
#  1      18 Years and 9 Months                     No            0.000000
#  2     18 Years and 10 Months                     NM            0.000000
#  3     18 Years and 11 Months                     No            0.000000
#  4      19 Years and 0 Months                     No            0.000000
#  ...                      ...                    ...                 ...
#  5995   31 Years and 6 Months                     No           35.104023
#  5996   31 Years and 7 Months                     No           35.104023
#  5997   31 Years and 8 Months                     No           35.104023
#  5998   31 Years and 9 Months                     No           35.104023
#  5999  31 Years and 10 Months                     No           35.104023
#
#       Amount_invested_monthly                 Payment_Behaviour  \
#  0          653.9822978912564    Low_spent_Large_value_payments
#  1         186.52023659780826   High_spent_Large_value_payments
#  2          250.4766071514879  High_spent_Medium_value_payments
#  3         143.98347272538896   High_spent_Large_value_payments
#  4          651.6394489063042   Low_spent_Medium_value_payments
#  ...                      ...                               ...
#  5995       60.97133255718485   High_spent_Large_value_payments
#  5996       54.18595028760385  High_spent_Medium_value_payments
#  5997       24.02847744864441   High_spent_Large_value_payments
#  5998      251.67258219721603    Low_spent_Large_value_payments
#  5999       167.1638651610451                            !@9#%8
#
#       Monthly_Balance Credit_Score
#  0         455.175202     Standard
#  1         892.637263     Standard
#  2         838.680893     Standard
#  3         935.174027     Standard
#  4         467.518051     Standard
#  ...              ...          ...
#  5995      479.866228         Poor
#  5996      496.651610         Poor
#  5997      516.809083         Poor
#  5998      319.164979     Standard
#  5999      393.673696         Poor
#
#  [6000 rows x 28 columns],
#             ID Customer_ID     Month     Name  Age          SSN  Occupation  \
#  0     0x219a2  CUS_0x89b4   January   Sarahu   26  581-11-9310  Accountant
#  1     0x219a3  CUS_0x89b4  February   Sarahu   26  581-11-9310  Accountant
#  2     0x219a4  CUS_0x89b4     March   Sarahu  26_  581-11-9310  Accountant
#  3     0x219a5  CUS_0x89b4     April   Sarahu   26  581-11-9310     _______
#  4     0x219a6  CUS_0x89b4       May   Sarahu   26  581-11-9310  Accountant
#  ...       ...         ...       ...      ...  ...          ...         ...
#  5995  0x23cc1  CUS_0xc166     April  Thomash   55  466-09-8122   Architect
#  5996  0x23cc2  CUS_0xc166       May  Thomash   55  466-09-8122   Architect
#  5997  0x23cc3  CUS_0xc166      June  Thomash   55  466-09-8122   Architect
#  5998  0x23cc4  CUS_0xc166      July      NaN   56  466-09-8122   Architect
#  5999  0x23cc5  CUS_0xc166    August  Thomash   56  466-09-8122   Architect
#
#       Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
#  0         11465.92             744.493333                  7  ...    Standard
#  1         11465.92             744.493333                  7  ...    Standard
#  2         11465.92             744.493333                  7  ...    Standard
#  3        11465.92_                    NaN                  7  ...    Standard
#  4         11465.92             744.493333                  7  ...           _
#  ...            ...                    ...                ...  ...         ...
#  5995     107836.32                    NaN                  3  ...    Standard
#  5996     107836.32            9251.360000                  3  ...           _
#  5997     107836.32            9251.360000                  3  ...    Standard
#  5998     107836.32            9251.360000                  3  ...    Standard
#  5999     107836.32            9251.360000                  3  ...    Standard
#
#        Outstanding_Debt Credit_Utilization_Ratio      Credit_History_Age  \
#  0              1422.93                38.466921   14 Years and 5 Months
#  1              1422.93                38.082899   14 Years and 6 Months
#  2              1422.93                34.416456   14 Years and 7 Months
#  3              1422.93                24.467137   14 Years and 8 Months
#  4              1422.93                34.547772                     NaN
#  ...                ...                      ...                     ...
#  5995           1045.39                31.321335  19 Years and 10 Months
#  5996           1045.39                31.068714  19 Years and 11 Months
#  5997           1045.39                29.400094   20 Years and 0 Months
#  5998           1045.39                41.071318   20 Years and 1 Months
#  5999           1045.39                28.112840   20 Years and 2 Months
#
#        Payment_of_Min_Amount Total_EMI_per_month Amount_invested_monthly  \
#  0                       Yes            0.000000        97.5137779378832
#  1                       Yes         2851.000000      10.630952548649931
#  2                       Yes            0.000000       97.65525769290214
#  3                       Yes            0.000000       84.06715397686786
#  4                       Yes            0.000000       65.78601596895011
#  ...                     ...                 ...                     ...
#  5995                     No          231.244069      1131.9835465765825
#  5996                     No          231.244069      112.86260394941631
#  5997                     No          231.244069       383.9922155732482
#  5998                     No          231.244069       101.0146095778987
#  5999                     No          231.244069       230.8861171127007
#
#                       Payment_Behaviour Monthly_Balance Credit_Score
#  0       Low_spent_Small_value_payments      266.935555     Standard
#  1     High_spent_Medium_value_payments      313.818381     Standard
#  2       Low_spent_Small_value_payments      266.794076     Standard
#  3       Low_spent_Small_value_payments      280.382179         Poor
#  4       Low_spent_Small_value_payments      298.663317         Poor
#  ...                                ...             ...          ...
#  5995    Low_spent_Small_value_payments             NaN     Standard
#  5996   High_spent_Large_value_payments      821.029327     Standard
#  5997    Low_spent_Large_value_payments      579.899715     Standard
#  5998   High_spent_Large_value_payments      832.877321         Poor
#  5999   High_spent_Small_value_payments      723.005814     Standard
#
#  [6000 rows x 28 columns],
#             ID Customer_ID     Month            Name   Age          SSN  \
#  0     0x1d352  CUS_0x35e9   January             NaN  2079  022-78-9607
#  1     0x1d353  CUS_0x35e9  February   Jessica Wohls    21  022-78-9607
#  2     0x1d354  CUS_0x35e9     March             NaN    21  022-78-9607
#  3     0x1d355  CUS_0x35e9     April   Jessica Wohls    21  022-78-9607
#  4     0x1d356  CUS_0x35e9       May   Jessica Wohls    22  022-78-9607
#  ...       ...         ...       ...             ...   ...          ...
#  5995  0x1f671  CUS_0xb982     April  Richard Leongk    52  688-83-9384
#  5996  0x1f672  CUS_0xb982       May  Richard Leongk    52  688-83-9384
#  5997  0x1f673  CUS_0xb982      June  Richard Leongk    52  688-83-9384
#  5998  0x1f674  CUS_0xb982      July  Richard Leongk    52  688-83-9384
#  5999  0x1f675  CUS_0xb982    August  Richard Leongk    52  688-83-9384
#
#        Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
#  0      Scientist      17805.21              1600.7675                  3  ...
#  1      Scientist      17805.21              1600.7675                  3  ...
#  2      Scientist      17805.21                    NaN                  3  ...
#  3      Scientist      17805.21              1600.7675                  3  ...
#  4      Scientist      17805.21              1600.7675                  3  ...
#  ...          ...           ...                    ...                ...  ...
#  5995  Accountant      59494.14                    NaN                  0  ...
#  5996     _______      59494.14              5162.8450                  0  ...
#  5997  Accountant      59494.14              5162.8450                  0  ...
#  5998  Accountant      59494.14              5162.8450                  0  ...
#  5999  Accountant      59494.14              5162.8450                  0  ...
#
#        Credit_Mix  Outstanding_Debt Credit_Utilization_Ratio  \
#  0              _           1879.94                27.531669
#  1       Standard           1879.94                32.614402
#  2       Standard           1879.94                39.613881
#  3       Standard           1879.94                29.947037
#  4       Standard           1879.94                34.215820
#  ...          ...               ...                      ...
#  5995        Good            662.71                27.500031
#  5996        Good            662.71                28.754529
#  5997        Good            662.71                41.539665
#  5998        Good            662.71                32.299001
#  5999        Good            662.71                31.206550
#
#            Credit_History_Age  Payment_of_Min_Amount Total_EMI_per_month  \
#  0      16 Years and 9 Months                    Yes           57.753932
#  1     16 Years and 10 Months                    Yes           57.753932
#  2     16 Years and 11 Months                    Yes           57.753932
#  3      17 Years and 0 Months                    Yes           57.753932
#  4      17 Years and 1 Months                     NM           57.753932
#  ...                      ...                    ...                 ...
#  5995                     NaN                     No           31.134101
#  5996   29 Years and 1 Months                     No           31.134101
#  5997                     NaN                     No           31.134101
#  5998   29 Years and 3 Months                     No           31.134101
#  5999   29 Years and 4 Months                     No           31.134101
#
#       Amount_invested_monthly                 Payment_Behaviour  \
#  0         137.33283654244576    Low_spent_Small_value_payments
#  1          92.46918018409448    Low_spent_Small_value_payments
#  2                        NaN   High_spent_Small_value_payments
#  3          114.2631108018038    Low_spent_Small_value_payments
#  4          70.86172768906061    Low_spent_Large_value_payments
#  ...                      ...                               ...
#  5995      142.95766571902703  High_spent_Medium_value_payments
#  5996      186.56627317911682  High_spent_Medium_value_payments
#  5997       247.2888344855052    Low_spent_Small_value_payments
#  5998      295.65517463013964   Low_spent_Medium_value_payments
#  5999      190.21074954468781    Low_spent_Small_value_payments
#
#       Monthly_Balance Credit_Score
#  0         254.989981     Standard
#  1         299.853638     Standard
#  2         272.443408     Standard
#  3         278.059707     Standard
#  4         301.461090     Standard
#  ...              ...          ...
#  5995      592.192734         Good
#  5996      548.584126         Good
#  5997      527.861565         Good
#  5998      469.495225     Standard
#  5999      584.939650     Standard
#
#  [6000 rows x 28 columns],
#             ID Customer_ID     Month     Name Age          SSN Occupation  \
#  0     0x1f67a  CUS_0x7080   January  Barkinp  39  026-31-3577    Teacher
#  1     0x1f67b  CUS_0x7080  February  Barkinp  39  026-31-3577    Teacher
#  2     0x1f67c  CUS_0x7080     March  Barkinp  39  026-31-3577    Teacher
#  3     0x1f67d  CUS_0x7080     April  Barkinp  39  026-31-3577    Teacher
#  4     0x1f67e  CUS_0x7080       May  Barkinp  39  026-31-3577    Teacher
#  ...       ...         ...       ...      ...  ..          ...        ...
#  5995  0x21999  CUS_0x6211     April  Spicerh  20  650-38-1015  Scientist
#  5996  0x2199a  CUS_0x6211       May  Spicerh  21  650-38-1015  Scientist
#  5997  0x2199b  CUS_0x6211      June  Spicerh  21  650-38-1015  Scientist
#  5998  0x2199c  CUS_0x6211      July  Spicerh  21  650-38-1015  Scientist
#  5999  0x2199d  CUS_0x6211    August  Spicerh  21  650-38-1015  Scientist
#
#       Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
#  0         58774.86                    NaN                  7  ...         Bad
#  1         58774.86            4796.905000                  7  ...         Bad
#  2      17036597.0_            4796.905000                  7  ...         Bad
#  3         58774.86            4796.905000                  7  ...         Bad
#  4         58774.86            4796.905000                  7  ...         Bad
#  ...            ...                    ...                ...  ...         ...
#  5995      33643.76            2835.646667                 10  ...    Standard
#  5996      33643.76            2835.646667                 10  ...    Standard
#  5997      33643.76            2835.646667                 10  ...    Standard
#  5998      33643.76            2835.646667                 10  ...           _
#  5999      33643.76            2835.646667                 10  ...    Standard
#
#        Outstanding_Debt Credit_Utilization_Ratio      Credit_History_Age  \
#  0              2083.26                31.656720   14 Years and 7 Months
#  1              2083.26                29.679718   14 Years and 8 Months
#  2              2083.26                31.643567   14 Years and 9 Months
#  3              2083.26                33.433503                     NaN
#  4              2083.26                30.227010  14 Years and 11 Months
#  ...                ...                      ...                     ...
#  5995           2379.75                27.822371   13 Years and 7 Months
#  5996           2379.75                35.062046   13 Years and 8 Months
#  5997           2379.75                37.307187   13 Years and 9 Months
#  5998           2379.75                27.934237  13 Years and 10 Months
#  5999           2379.75                36.994510  13 Years and 11 Months
#
#        Payment_of_Min_Amount Total_EMI_per_month Amount_invested_monthly  \
#  0                       Yes          290.944962       294.8536336532485
#  1                       Yes          290.944962       86.45327578613144
#  2                       Yes          290.944962         86.355850183324
#  3                       Yes          290.944962      167.34775172914203
#  4                       Yes          290.944962       567.8636233869818
#  ...                     ...                 ...                     ...
#  5995                    Yes           36.681715       283.5755892166151
#  5996                    Yes           36.681715       44.23315266366881
#  5997                    Yes           36.681715       77.96008588925906
#  5998                    Yes           36.681715        57.2713700042119
#  5999                    Yes           36.681715        73.5431843575069
#
#                       Payment_Behaviour     Monthly_Balance Credit_Score
#  0      Low_spent_Medium_value_payments  173.89190463374646         Poor
#  1      High_spent_Small_value_payments  362.29226250086367         Poor
#  2     High_spent_Medium_value_payments  352.38968810367106         Poor
#  3     High_spent_Medium_value_payments   271.3977865578529     Standard
#  4       Low_spent_Small_value_payments                 NaN     Standard
#  ...                                ...                 ...          ...
#  5995    Low_spent_Small_value_payments  253.30736203204003         Poor
#  5996  High_spent_Medium_value_payments  452.64979858498634         Poor
#  5997   High_spent_Small_value_payments  428.92286535939616     Standard
#  5998  High_spent_Medium_value_payments   439.6115812444432     Standard
#  5999   High_spent_Small_value_payments   433.3397668911482         Poor
#
#  [6000 rows x 28 columns],
#             ID Customer_ID     Month                      Name Age  \
#  0     0x1b02a  CUS_0x1d1b   January                   Araxiac  20
#  1     0x1b02b  CUS_0x1d1b  February                   Araxiac  20
#  2     0x1b02c  CUS_0x1d1b     March                   Araxiac  20
#  3     0x1b02d  CUS_0x1d1b     April                   Araxiac  20
#  4     0x1b02e  CUS_0x1d1b       May                   Araxiac  20
#  ...       ...         ...       ...                       ...  ..
#  5995  0x1d349  CUS_0x63b0     April  Economics Correspondentc  41
#  5996  0x1d34a  CUS_0x63b0       May  Economics Correspondentc  41
#  5997  0x1d34b  CUS_0x63b0      June                       NaN  41
#  5998  0x1d34c  CUS_0x63b0      July  Economics Correspondentc  41
#  5999  0x1d34d  CUS_0x63b0    August  Economics Correspondentc  41
#
#                SSN Occupation Annual_Income  Monthly_Inhand_Salary  \
#  0       #F%$D@*&8    Manager     152574.76           12547.563330
#  1     566-75-8198    Manager     152574.76           12547.563330
#  2     566-75-8198    Manager     152574.76                    NaN
#  3     566-75-8198    Manager     152574.76           12547.563330
#  4     566-75-8198    Manager     152574.76           12547.563330
#  ...           ...        ...           ...                    ...
#  5995    #F%$D@*&8    _______      89705.92                    NaN
#  5996  951-45-7111  Architect      89705.92            7678.493333
#  5997  951-45-7111  Architect      89705.92            7678.493333
#  5998  951-45-7111    _______      89705.92            7678.493333
#  5999  951-45-7111  Architect      89705.92            7678.493333
#
#        Num_Bank_Accounts  ...  Credit_Mix  Outstanding_Debt  \
#  0                     2  ...        Good            754.8_
#  1                     2  ...           _             754.8
#  2                     2  ...           _             754.8
#  3                     2  ...        Good             754.8
#  4                     2  ...        Good             754.8
#  ...                 ...  ...         ...               ...
#  5995                  6  ...    Standard            434.95
#  5996                  6  ...    Standard            434.95
#  5997                  6  ...    Standard            434.95
#  5998                  6  ...    Standard            434.95
#  5999                  6  ...    Standard            434.95
#
#       Credit_Utilization_Ratio      Credit_History_Age  Payment_of_Min_Amount  \
#  0                   38.632872   20 Years and 1 Months                     No
#  1                   35.208889   20 Years and 2 Months                     NM
#  2                   42.901507   20 Years and 3 Months                     No
#  3                   30.699354   20 Years and 4 Months                     No
#  4                   37.484783   20 Years and 5 Months                     No
#  ...                       ...                     ...                    ...
#  5995                27.772688  26 Years and 10 Months                     NM
#  5996                30.222749  26 Years and 11 Months                     No
#  5997                30.216185   27 Years and 0 Months                     No
#  5998                36.943411                     NaN                     NM
#  5999                36.907990   27 Years and 2 Months                     No
#
#       Total_EMI_per_month Amount_invested_monthly  \
#  0             205.484843       974.5606914556856
#  1             205.484843       982.7453087717968
#  2             205.484843      338.01429339922765
#  3             205.484843       579.2748624035772
#  4             205.484843       730.2802363715598
#  ...                  ...                     ...
#  5995          269.367539       309.3712868521025
#  5996          269.367539      111.88108856422451
#  5997          269.367539       185.6542536654386
#  5998          269.367539               __10000__
#  5999          269.367539       129.1272184003565
#
#                       Payment_Behaviour     Monthly_Balance Credit_Score
#  0       Low_spent_Small_value_payments    364.710798997342     Standard
#  1      Low_spent_Medium_value_payments  346.52618168123087         Poor
#  2      Low_spent_Medium_value_payments      991.2571970538         Poor
#  3       Low_spent_Small_value_payments   759.9966280494504         Poor
#  4       Low_spent_Large_value_payments   588.9912540814679         Poor
#  ...                                ...                 ...          ...
#  5995   Low_spent_Medium_value_payments   469.1105079907733         Poor
#  5996  High_spent_Medium_value_payments   636.6007062786513         Poor
#  5997   High_spent_Large_value_payments   552.8275411774372         Poor
#  5998    Low_spent_Small_value_payments    80.8293407820467     Standard
#  5999   High_spent_Large_value_payments   609.3545764425193     Standard
#
#  [6000 rows x 28 columns],
#             ID Customer_ID     Month        Name    Age          SSN  \
#  0     0x18d02   CUS_0x9ca   January  Vellacottf     38  401-46-8317
#  1     0x18d03   CUS_0x9ca  February  Vellacottf  8523_  401-46-8317
#  2     0x18d04   CUS_0x9ca     March         NaN     38  401-46-8317
#  3     0x18d05   CUS_0x9ca     April  Vellacottf     38  401-46-8317
#  4     0x18d06   CUS_0x9ca       May  Vellacottf     38  401-46-8317
#  ...       ...         ...       ...         ...    ...          ...
#  5995  0x1b021  CUS_0x2b7e     April     Andreaz     28  683-88-7105
#  5996  0x1b022  CUS_0x2b7e       May     Andreaz     28  683-88-7105
#  5997  0x1b023  CUS_0x2b7e      June     Andreaz     28  683-88-7105
#  5998  0x1b024  CUS_0x2b7e      July     Andreaz     28  683-88-7105
#  5999  0x1b025  CUS_0x2b7e    August     Andreaz     28  683-88-7105
#
#        Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
#  0       Mechanic       60530.7            4962.225000                  3  ...
#  1       Mechanic       60530.7            4962.225000                  3  ...
#  2       Mechanic       60530.7            4962.225000                  3  ...
#  3       Mechanic       60530.7            4962.225000                  3  ...
#  4       Mechanic       60530.7            4962.225000                  3  ...
#  ...          ...           ...                    ...                ...  ...
#  5995     _______      28849.66            2142.138333                  4  ...
#  5996  Accountant      28849.66            2142.138333                  4  ...
#  5997  Accountant      28849.66            2142.138333                  4  ...
#  5998  Accountant      28849.66            2142.138333                  4  ...
#  5999  Accountant      28849.66            2142.138333                  4  ...
#
#        Credit_Mix  Outstanding_Debt Credit_Utilization_Ratio  \
#  0       Standard            361.83                39.069245
#  1       Standard            361.83                25.572516
#  2       Standard            361.83                28.985767
#  3       Standard            361.83                26.210677
#  4       Standard            361.83                39.427326
#  ...          ...               ...                      ...
#  5995    Standard           2496.14                30.852473
#  5996           _           2496.14                32.309244
#  5997    Standard           2496.14                35.449194
#  5998    Standard           2496.14                36.350793
#  5999    Standard           2496.14                38.748623
#
#            Credit_History_Age  Payment_of_Min_Amount Total_EMI_per_month  \
#  0                        NaN                     No           40.763173
#  1     28 Years and 11 Months                     No           40.763173
#  2      29 Years and 0 Months                     No           40.763173
#  3      29 Years and 1 Months                     NM           40.763173
#  4      29 Years and 2 Months                     NM           40.763173
#  ...                      ...                    ...                 ...
#  5995   12 Years and 7 Months                    Yes           39.173568
#  5996   12 Years and 8 Months                    Yes           39.173568
#  5997   12 Years and 9 Months                    Yes           39.173568
#  5998  12 Years and 10 Months                    Yes           39.173568
#  5999  12 Years and 11 Months                     NM           39.173568
#
#       Amount_invested_monthly                 Payment_Behaviour  \
#  0          646.2799895980319    Low_spent_Small_value_payments
#  1         455.61391483579087   Low_spent_Medium_value_payments
#  2          225.3827659701968   Low_spent_Medium_value_payments
#  3          75.93221359716077   High_spent_Large_value_payments
#  4          96.25115895153552  High_spent_Medium_value_payments
#  ...                      ...                               ...
#  5995       77.78989814640211  High_spent_Medium_value_payments
#  5996       78.44409804026186    Low_spent_Small_value_payments
#  5997        63.8994488817266   High_spent_Small_value_payments
#  5998      173.03528830099324    Low_spent_Small_value_payments
#  5999      14.818574271542209   High_spent_Large_value_payments
#
#       Monthly_Balance Credit_Score
#  0          99.179338     Standard
#  1         279.845413     Standard
#  2         510.076561     Standard
#  3         619.527114     Standard
#  4         609.208168     Standard
#  ...              ...          ...
#  5995      347.250367         Poor
#  5996      386.596167         Poor
#  5997      371.140817         Poor
#  5998      292.004977     Standard
#  5999      400.221691     Standard
#
#  [6000 rows x 28 columns],
#             ID Customer_ID     Month      Name   Age          SSN  \
#  0     0x169da  CUS_0x1d56   January  Laurenti    30  200-30-0736
#  1     0x169db  CUS_0x1d56  February  Laurenti    30  200-30-0736
#  2     0x169dc  CUS_0x1d56     March  Laurenti    30  200-30-0736
#  3     0x169dd  CUS_0x1d56     April  Laurenti    30  200-30-0736
#  4     0x169de  CUS_0x1d56       May  Laurenti    30  200-30-0736
#  ...       ...         ...       ...       ...   ...          ...
#  5995  0x18cf9  CUS_0x87e6     April     K. Rg    22  239-23-3959
#  5996  0x18cfa  CUS_0x87e6       May     K. Rg    22  239-23-3959
#  5997  0x18cfb  CUS_0x87e6      June     K. Rg  4841  239-23-3959
#  5998  0x18cfc  CUS_0x87e6      July     K. Rg    23  239-23-3959
#  5999  0x18cfd  CUS_0x87e6    August     K. Rg    23  239-23-3959
#
#           Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
#  0     Media_Manager      53127.72                    NaN                  7
#  1     Media_Manager      53127.72             4655.31000                  7
#  2     Media_Manager      53127.72             4655.31000                  7
#  3     Media_Manager      53127.72             4655.31000                  7
#  4     Media_Manager     53127.72_             4655.31000                  7
#  ...             ...           ...                    ...                ...
#  5995         Doctor     122135.12            10125.92667                  2
#  5996         Doctor     122135.12            10125.92667                  2
#  5997         Doctor     122135.12            10125.92667                  2
#  5998         Doctor     122135.12            10125.92667                  2
#  5999         Doctor     122135.12            10125.92667                  2
#
#        ...  Credit_Mix  Outstanding_Debt Credit_Utilization_Ratio  \
#  0     ...    Standard          1752.55_                36.732851
#  1     ...    Standard           1752.55                24.639994
#  2     ...    Standard           1752.55                24.453685
#  3     ...    Standard           1752.55                23.940988
#  4     ...    Standard           1752.55                31.065417
#  ...   ...         ...               ...                      ...
#  5995  ...        Good           1384.06                30.376533
#  5996  ...        Good           1384.06                33.128355
#  5997  ...           _           1384.06                30.669383
#  5998  ...        Good           1384.06                40.288118
#  5999  ...        Good           1384.06                38.830600
#
#            Credit_History_Age  Payment_of_Min_Amount Total_EMI_per_month  \
#  0     19 Years and 11 Months                     NM           87.578353
#  1      20 Years and 0 Months                     NM           87.578353
#  2      20 Years and 1 Months                    Yes        78484.000000
#  3                        NaN                    Yes           87.578353
#  4      20 Years and 3 Months                     NM           87.578353
#  ...                      ...                    ...                 ...
#  5995  17 Years and 10 Months                     No           53.472240
#  5996  17 Years and 11 Months                     No           53.472240
#  5997   18 Years and 0 Months                     NM        76073.000000
#  5998   18 Years and 1 Months                     No           53.472240
#  5999   18 Years and 2 Months                     No           53.472240
#
#       Amount_invested_monthly                 Payment_Behaviour  \
#  0          309.2879347337052    Low_spent_Small_value_payments
#  1         158.01061049825032  High_spent_Medium_value_payments
#  2          515.4099893454119    Low_spent_Small_value_payments
#  3          62.08284715588783  High_spent_Medium_value_payments
#  4          118.1496758655061    Low_spent_Large_value_payments
#  ...                      ...                               ...
#  5995       531.3487810647484   High_spent_Small_value_payments
#  5996       825.6915014509021    Low_spent_Large_value_payments
#  5997      1065.7247946896077    Low_spent_Small_value_payments
#  5998       390.5988237653815   High_spent_Small_value_payments
#  5999       425.7043435375258  High_spent_Medium_value_payments
#
#           Monthly_Balance Credit_Score
#  0     358.66471213232626         Poor
#  1     469.94203636778093         Poor
#  2     152.54265752061963         Poor
#  3      565.8697997101435         Poor
#  4      529.8029710005253         Poor
#  ...                  ...          ...
#  5995   687.7716454181157     Standard
#  5996  403.42892503196197     Standard
#  5997   183.3956317932566     Standard
#  5998   828.5216027174828         Poor
#  5999   783.4160829453383         Poor
#
#  [6000 rows x 28 columns],
#             ID Customer_ID     Month             Name   Age          SSN  \
#  0     0x146b2  CUS_0x6fbf   January          imartew    14  824-59-3661
#  1     0x146b3  CUS_0x6fbf  February          imartew    14  824-59-3661
#  2     0x146b4  CUS_0x6fbf     March          imartew    14  824-59-3661
#  3     0x146b5  CUS_0x6fbf     April          imartew    14  824-59-3661
#  4     0x146b6  CUS_0x6fbf       May          imartew  8389  824-59-3661
#  ...       ...         ...       ...              ...   ...          ...
#  5995  0x169d1  CUS_0x9bf3     April  Jonathan Cableo    42  458-76-0289
#  5996  0x169d2  CUS_0x9bf3       May  Jonathan Cableo    43  458-76-0289
#  5997  0x169d3  CUS_0x9bf3      June  Jonathan Cableo    43  458-76-0289
#  5998  0x169d4  CUS_0x9bf3      July  Jonathan Cableo    43  458-76-0289
#  5999  0x169d5  CUS_0x9bf3    August  Jonathan Cableo    43  458-76-0289
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
#  0        Lawyer      32991.92                    NaN                  7  ...
#  1        Lawyer      32991.92                    NaN                  7  ...
#  2        Lawyer      32991.92            2682.326667                  7  ...
#  3        Lawyer      32991.92            2682.326667                  7  ...
#  4        Lawyer      32991.92            2682.326667                  7  ...
#  ...         ...           ...                    ...                ...  ...
#  5995    Teacher      34571.53            2854.960833                  5  ...
#  5996    Teacher      34571.53            2854.960833                  5  ...
#  5997    Teacher      34571.53            2854.960833                  5  ...
#  5998    _______      34571.53            2854.960833                  5  ...
#  5999    _______      34571.53                    NaN                  5  ...
#
#        Credit_Mix  Outstanding_Debt Credit_Utilization_Ratio  \
#  0            Bad           1295.76                22.904423
#  1            Bad           1295.76                32.822305
#  2            Bad           1295.76                25.076097
#  3            Bad           1295.76                33.929422
#  4              _           1295.76                35.503452
#  ...          ...               ...                      ...
#  5995        Good             58.37                38.551211
#  5996        Good             58.37                25.889314
#  5997        Good             58.37                29.015988
#  5998           _             58.37                33.927326
#  5999        Good             58.37                29.721151
#
#            Credit_History_Age  Payment_of_Min_Amount Total_EMI_per_month  \
#  0      9 Years and 10 Months                    Yes          124.606203
#  1      9 Years and 11 Months                    Yes          124.606203
#  2      10 Years and 0 Months                    Yes          124.606203
#  3      10 Years and 1 Months                    Yes          124.606203
#  4                        NaN                    Yes          124.606203
#  ...                      ...                    ...                 ...
#  5995   26 Years and 7 Months                     No           41.836331
#  5996   26 Years and 8 Months                     NM           41.836331
#  5997   26 Years and 9 Months                     No        66504.000000
#  5998  26 Years and 10 Months                     No           41.836331
#  5999  26 Years and 11 Months                     No           41.836331
#
#       Amount_invested_monthly                 Payment_Behaviour  \
#  0                        NaN    Low_spent_Large_value_payments
#  1         183.42177521499588   High_spent_Small_value_payments
#  2                        NaN  High_spent_Medium_value_payments
#  3         113.94982443444972  High_spent_Medium_value_payments
#  4          30.46394089509861  High_spent_Medium_value_payments
#  ...                      ...                               ...
#  5995       73.88979018421395   High_spent_Large_value_payments
#  5996          61.14348348882   High_spent_Small_value_payments
#  5997       31.70826206832223  High_spent_Medium_value_payments
#  5998       138.5775052325155    Low_spent_Small_value_payments
#  5999      303.86950857122054    Low_spent_Small_value_payments
#
#       Monthly_Balance Credit_Score
#  0         346.146441         Poor
#  1         220.204689         Poor
#  2         303.648904         Poor
#  3         279.676640         Poor
#  4         363.162523         Poor
#  ...              ...          ...
#  5995      409.769962         Good
#  5996      442.516269         Good
#  5997      461.951490         Good
#  5998      395.082247     Standard
#  5999      229.790243     Standard
#
#  [6000 rows x 28 columns],
#             ID Customer_ID     Month     Name  Age          SSN  Occupation  \
#  0     0x1238a  CUS_0x8018   January   Smitab   52  456-03-1565    Mechanic
#  1     0x1238b  CUS_0x8018  February   Smitab  52_  456-03-1565    Mechanic
#  2     0x1238c  CUS_0x8018     March   Smitab   52    #F%$D@*&8    Mechanic
#  3     0x1238d  CUS_0x8018     April   Smitab   52  456-03-1565    Mechanic
#  4     0x1238e  CUS_0x8018       May   Smitab   52  456-03-1565    Mechanic
#  ...       ...         ...       ...      ...  ...          ...         ...
#  5995  0x146a9  CUS_0x9d62     April  Laurenz   37  533-48-6343  Accountant
#  5996  0x146aa  CUS_0x9d62       May  Laurenz   37  533-48-6343  Accountant
#  5997  0x146ab  CUS_0x9d62      June  Laurenz   37  533-48-6343  Accountant
#  5998  0x146ac  CUS_0x9d62      July  Laurenz   37    #F%$D@*&8  Accountant
#  5999  0x146ad  CUS_0x9d62    August  Laurenz   37  533-48-6343  Accountant
#
#       Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
#  0          49937.4            4079.450000                  3  ...    Standard
#  1          49937.4                    NaN                  3  ...           _
#  2          49937.4            4079.450000                  3  ...    Standard
#  3          49937.4                    NaN                  3  ...    Standard
#  4          49937.4            3670.800284                  3  ...    Standard
#  ...            ...                    ...                ...  ...         ...
#  5995      60340.08            4327.369161                  2  ...           _
#  5996     60340.08_                    NaN                  2  ...        Good
#  5997      60340.08            4327.369161                  2  ...        Good
#  5998      60340.08            4327.369161                  2  ...        Good
#  5999      60340.08            4327.369161                  2  ...        Good
#
#        Outstanding_Debt Credit_Utilization_Ratio      Credit_History_Age  \
#  0              1069.53                27.480730  15 Years and 10 Months
#  1              1069.53                34.922443  15 Years and 11 Months
#  2              1069.53                33.004723   16 Years and 0 Months
#  3              1069.53                27.939520   16 Years and 1 Months
#  4              1069.53                26.166821   16 Years and 2 Months
#  ...                ...                      ...                     ...
#  5995             638.7                38.393480   18 Years and 4 Months
#  5996             638.7                33.248144   18 Years and 5 Months
#  5997             638.7                24.981446   18 Years and 6 Months
#  5998             638.7                28.310482   18 Years and 7 Months
#  5999             638.7                22.848169   18 Years and 8 Months
#
#        Payment_of_Min_Amount Total_EMI_per_month Amount_invested_monthly  \
#  0                       Yes           47.217598       155.4781676845499
#  1                       Yes           47.217598       40.51208510313344
#  2                       Yes           47.217598      57.634114494896316
#  3                       Yes           47.217598               __10000__
#  4                        NM          455.867315      263.62313812689314
#  ...                     ...                 ...                     ...
#  5995                     No          577.394027       310.6289228025095
#  5996                     No          577.394027       89.01535457124074
#  5997                     No          577.394027      193.38049000871385
#  5998                     No        43841.000000       382.3862850626289
#  5999                     NM          577.394027       575.7488410112658
#
#                       Payment_Behaviour Monthly_Balance Credit_Score
#  0     High_spent_Medium_value_payments      455.249234     Standard
#  1      High_spent_Large_value_payments      560.215317     Standard
#  2     High_spent_Medium_value_payments      553.093287     Standard
#  3       Low_spent_Small_value_payments      469.077731     Standard
#  4       Low_spent_Small_value_payments      387.104264     Standard
#  ...                                ...             ...          ...
#  5995   High_spent_Small_value_payments      300.781890         Good
#  5996   High_spent_Large_value_payments      502.395458         Good
#  5997  High_spent_Medium_value_payments      408.030322     Standard
#  5998    Low_spent_Small_value_payments      259.024527         Good
#  5999    Low_spent_Small_value_payments       65.661971         Good
#
#  [6000 rows x 28 columns],
#            ID Customer_ID     Month         Name  Age          SSN  \
#  0     0xba12  CUS_0x7b94   January       Rochay   18  449-05-9106
#  1     0xba13  CUS_0x7b94  February       Rochay   18  449-05-9106
#  2     0xba14  CUS_0x7b94     March       Rochay  18_  449-05-9106
#  3     0xba15  CUS_0x7b94     April       Rochay   18  449-05-9106
#  4     0xba16  CUS_0x7b94       May       Rochay   18  449-05-9106
#  ...      ...         ...       ...          ...  ...          ...
#  5995  0xdd31  CUS_0x8763     April  Viswanathay   24  038-13-2033
#  5996  0xdd32  CUS_0x8763       May  Viswanathay   24  038-13-2033
#  5997  0xdd33  CUS_0x8763      June  Viswanathay   24    #F%$D@*&8
#  5998  0xdd34  CUS_0x8763      July          NaN   24  038-13-2033
#  5999  0xdd35  CUS_0x8763    August  Viswanathay   24  038-13-2033
#
#           Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
#  0     Media_Manager     107427.99             8868.33250                  8
#  1     Media_Manager     107427.99             8868.33250                  8
#  2     Media_Manager     107427.99             8868.33250                  8
#  3     Media_Manager    107427.99_             8868.33250                  8
#  4     Media_Manager     107427.99             8868.33250                  8
#  ...             ...           ...                    ...                ...
#  5995      Scientist     7536.015_              589.00125                  4
#  5996      Scientist      7536.015              589.00125                  4
#  5997      Scientist      7536.015              589.00125                  4
#  5998      Scientist      7536.015              589.00125                  4
#  5999      Scientist      7536.015              589.00125                  4
#
#        ...  Credit_Mix  Outstanding_Debt Credit_Utilization_Ratio  \
#  0     ...    Standard           1124.02                33.427883
#  1     ...           _           1124.02                44.195949
#  2     ...    Standard           1124.02                31.303461
#  3     ...    Standard           1124.02                32.151647
#  4     ...           _           1124.02                28.410979
#  ...   ...         ...               ...                      ...
#  5995  ...           _            1276.4                29.326872
#  5996  ...           _            1276.4                32.661719
#  5997  ...           _            1276.4                37.741994
#  5998  ...           _            1276.4                37.390042
#  5999  ...    Standard            1276.4                29.115090
#
#            Credit_History_Age  Payment_of_Min_Amount Total_EMI_per_month  \
#  0      31 Years and 7 Months                     No        52126.000000
#  1      31 Years and 8 Months                     No           55.659101
#  2      31 Years and 9 Months                     No           55.659101
#  3     31 Years and 10 Months                     No           55.659101
#  4     31 Years and 11 Months                     No           55.659101
#  ...                      ...                    ...                 ...
#  5995   20 Years and 0 Months                    Yes           17.852927
#  5996   20 Years and 1 Months                     NM           17.852927
#  5997   20 Years and 2 Months                    Yes           17.852927
#  5998   20 Years and 3 Months                    Yes           17.852927
#  5999   20 Years and 4 Months                    Yes           17.852927
#
#       Amount_invested_monthly                 Payment_Behaviour  \
#  0         260.00419834481585  High_spent_Medium_value_payments
#  1         193.75036600987443   High_spent_Large_value_payments
#  2         214.11879374453116    Low_spent_Large_value_payments
#  3          601.8334277197184   Low_spent_Medium_value_payments
#  4          356.2755674389546   High_spent_Small_value_payments
#  ...                      ...                               ...
#  5995        40.8542554108962    Low_spent_Large_value_payments
#  5996        25.0194064884154    Low_spent_Small_value_payments
#  5997       51.36082164520265   Low_spent_Medium_value_payments
#  5998      21.371508515379624   High_spent_Small_value_payments
#  5999       58.90196044861632   Low_spent_Medium_value_payments
#
#          Monthly_Balance Credit_Score
#  0     821.1699506897244     Standard
#  1     877.4237830246658     Standard
#  2     887.0553552900093     Standard
#  3     509.3407213148218     Standard
#  4     734.8985815955858     Standard
#  ...                 ...          ...
#  5995   270.192942636879         Poor
#  5996  306.0277915593598     Standard
#  5997  269.6863764025726         Poor
#  5998  279.6756895323956         Poor
#  5999  262.1452375991589         Poor
#
# ...
#  5998   16 Years and 1 Months                    Yes            0.000000
#  5999   16 Years and 2 Months                    Yes            0.000000
#
#       Amount_invested_monthly                Payment_Behaviour  \
#  0         144.32152591037604  High_spent_Large_value_payments
#  1                  __10000__                           !@9#%8
#  2         139.41638078622734  High_spent_Large_value_payments
#  3          573.9865627619063  Low_spent_Medium_value_payments
#  4         111.60239773434185  High_spent_Large_value_payments
#  ...                      ...                              ...
#  5995      316.20328976123835                           !@9#%8
#  5996      1237.2276770009566  Low_spent_Medium_value_payments
#  5997      1600.6891092706255   Low_spent_Small_value_payments
#  5998       254.0088192098381                           !@9#%8
#  5999       589.7341625245207  High_spent_Small_value_payments
#
#           Monthly_Balance Credit_Score
#  0       623.580527109982          NaN
#  1       622.875977954279          NaN
#  2      628.4856722341308          NaN
#  3     233.91549025845188          NaN
#  4      988.5971510809571          NaN
#  ...                  ...          ...
#  5995   413.6126085918452          NaN
#  5996   258.3803229990435          NaN
#  5997                 NaN          NaN
#  5998   1211.599180790162          NaN
#  5999   885.8738374754791          NaN
#
#  [6000 rows x 28 columns],
#             ID Customer_ID      Month       Name  Age          SSN  Occupation  \
#  0      0xe8fa  CUS_0x781a  September      Miken   33  176-88-1274    Engineer
#  1      0xe8fb  CUS_0x781a    October      Miken   33  176-88-1274    Engineer
#  2      0xe8fc  CUS_0x781a   November      Miken   33  176-88-1274    Engineer
#  3      0xe8fd  CUS_0x781a   December      Miken  34_  176-88-1274    Engineer
#  4      0xe906  CUS_0x54bd  September        NaN   26  389-25-0255  Journalist
#  ...       ...         ...        ...        ...  ...          ...         ...
#  5995  0x12f35  CUS_0x92df   December  Kajimotoh   32  756-71-3400  Accountant
#  5996  0x12f3e  CUS_0xb0e5  September     Laurar   42  934-39-5678    Mechanic
#  5997  0x12f3f  CUS_0xb0e5    October     Laurar   42  934-39-5678    Mechanic
#  5998  0x12f40  CUS_0xb0e5   November     Laurar   42  934-39-5678    Mechanic
#  5999  0x12f41  CUS_0xb0e5   December     Laurar   42  934-39-5678    Mechanic
#
#       Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
#  0         41770.21            3652.850833                209  ...        Good
#  1         41770.21            3652.850833                  0  ...        Good
#  2         41770.21            3652.850833                  0  ...           _
#  3        41770.21_            3652.850833                  0  ...        Good
#  4        167753.52           13102.045570                  3  ...        Good
#  ...            ...                    ...                ...  ...         ...
#  5995      20168.99            1682.083696                  5  ...    Standard
#  5996      17908.01            1152.676742                  5  ...        Good
#  5997      17908.01            1152.676742                  5  ...           _
#  5998      17908.01            1152.676742                  5  ...        Good
#  5999      17908.01            1152.676742                  5  ...        Good
#
#        Outstanding_Debt Credit_Utilization_Ratio     Credit_History_Age  \
#  0              1174.56                35.144209  19 Years and 6 Months
#  1              1174.56                33.719904  19 Years and 7 Months
#  2              1174.56                28.380794  19 Years and 8 Months
#  3              1174.56                28.271338  19 Years and 9 Months
#  4              1079.59                45.105521  29 Years and 4 Months
#  ...                ...                      ...                    ...
#  5995           2043.24                24.090078  16 Years and 9 Months
#  5996           1456.12                37.196254  19 Years and 0 Months
#  5997           1456.12                34.170485  19 Years and 1 Months
#  5998           1456.12                25.142276  19 Years and 2 Months
#  5999           1456.12                28.332975  19 Years and 3 Months
#
#        Payment_of_Min_Amount Total_EMI_per_month Amount_invested_monthly  \
#  0                        No           51.922734      370.50709232661075
#  1                        No           51.922734      108.72851326990887
#  2                        No           51.922734      111.46278196857864
#  3                        No           51.922734       77.15776008894765
#  4                        No         1190.730221      212.58234057076282
#  ...                     ...                 ...                     ...
#  5995                    Yes          172.961045       114.5041631960206
#  5996                     No          179.781031        119.718390555982
#  5997                     No          179.781031       84.74229760469149
#  5998                     No          179.781031      120.86027403980934
#  5999                     NM          179.781031       40.73950079283187
#
#                       Payment_Behaviour     Monthly_Balance Credit_Score
#  0      Low_spent_Medium_value_payments   222.8552566956551          NaN
#  1       Low_spent_Large_value_payments  474.63383575235684          NaN
#  2     High_spent_Medium_value_payments  451.89956705368724          NaN
#  3                               !@9#%8   486.2045889333181          NaN
#  4     High_spent_Medium_value_payments   1183.647869630335          NaN
#  ...                                ...                 ...          ...
#  5995   High_spent_Small_value_payments   250.3751782917337          NaN
#  5996   Low_spent_Medium_value_payments   275.7914198097781          NaN
#  5997   High_spent_Small_value_payments   290.7675127610686          NaN
#  5998    Low_spent_Small_value_payments  284.64953632595075          NaN
#  5999  High_spent_Medium_value_payments   324.7703095729282          NaN
#
#  [6000 rows x 28 columns],
#             ID Customer_ID      Month           Name Age          SSN  \
#  0     0x2023a  CUS_0xb38f  September       Koh Guib  34  076-83-7903
#  1     0x2023b  CUS_0xb38f    October       Koh Guib  34  076-83-7903
#  2     0x2023c  CUS_0xb38f   November            NaN  34  076-83-7903
#  3     0x2023d  CUS_0xb38f   December       Koh Guib  34  076-83-7903
#  4     0x20246  CUS_0xac7d  September    Luke Jeffsw  22  111-11-3343
#  ...       ...         ...        ...            ...  ..          ...
#  5995  0x24875  CUS_0x194b   December  Liza Dobkinan  30  661-41-7229
#  5996  0x2487e  CUS_0xadf0  September     Chadbourna  44  076-89-6350
#  5997  0x2487f  CUS_0xadf0    October     Chadbourna  44  076-89-6350
#  5998  0x24880  CUS_0xadf0   November     Chadbourna  44  076-89-6350
#  5999  0x24881  CUS_0xadf0   December     Chadbourna  44  076-89-6350
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
#  0      Musician       56500.7            4448.062323                  2  ...
#  1      Musician       56500.7            4448.062323                  2  ...
#  2      Musician       56500.7            4448.062323                  2  ...
#  3      Musician       56500.7            4448.062323                  2  ...
#  4       Teacher     38882.52_            3186.210000                  7  ...
#  ...         ...           ...                    ...                ...  ...
#  5995   Engineer     161272.04           13312.336670                  1  ...
#  5996    Manager     109182.72            9055.560000                  1  ...
#  5997    _______     109182.72            9055.560000                  1  ...
#  5998    Manager     109182.72                    NaN                  1  ...
#  5999    Manager     109182.72            9055.560000                  1  ...
#
#        Credit_Mix  Outstanding_Debt Credit_Utilization_Ratio  \
#  0           Good            991.98                36.630898
#  1              _            991.98                29.039793
#  2           Good            991.98                30.798733
#  3              _            991.98                22.860793
#  4       Standard            1191.5                23.761172
#  ...          ...               ...                      ...
#  5995        Good            705.53                25.731308
#  5996        Good            623.35                37.873894
#  5997        Good            623.35                31.941888
#  5998        Good            623.35                34.517059
#  5999        Good            623.35                43.836089
#
#            Credit_History_Age  Payment_of_Min_Amount Total_EMI_per_month  \
#  0     32 Years and 11 Months                     No          396.340762
#  1      33 Years and 0 Months                     NM          396.340762
#  2      33 Years and 1 Months                     No          396.340762
#  3      33 Years and 2 Months                     No          396.340762
#  4      24 Years and 1 Months                    Yes           61.055085
#  ...                      ...                    ...                 ...
#  5995   20 Years and 1 Months                     No          288.013678
#  5996   31 Years and 7 Months                     No           46.424707
#  5997   31 Years and 8 Months                     No           46.424707
#  5998   31 Years and 9 Months                     No           46.424707
#  5999  31 Years and 10 Months                     No           46.424707
#
#       Amount_invested_monthly                 Payment_Behaviour  \
#  0          379.5111434496912    Low_spent_Small_value_payments
#  1                  __10000__    Low_spent_Large_value_payments
#  2         303.83173376901794    Low_spent_Small_value_payments
#  3          581.6754634108513    Low_spent_Small_value_payments
#  4                  __10000__  High_spent_Medium_value_payments
#  ...                      ...                               ...
#  5995      1270.3367045210064    Low_spent_Small_value_payments
#  5996      138.78869733207074   High_spent_Large_value_payments
#  5997       310.1348443318155  High_spent_Medium_value_payments
#  5998                     NaN                            !@9#%8
#  5999               __10000__   High_spent_Large_value_payments
#
#           Monthly_Balance Credit_Score
#  0     308.01660410050675          NaN
#  1     259.09529882588953          NaN
#  2     383.69601378117994          NaN
#  3     105.85228413934664          NaN
#  4     432.65506171644387          NaN
#  ...                  ...          ...
#  5995  62.883283948917104          NaN
#  5996   960.3425957771091          NaN
#  5997   798.9964487773642          NaN
#  5998  1000.1769535194679          NaN
#  5999   866.0719267467914          NaN
#
#  [6000 rows x 28 columns],
#            ID Customer_ID      Month             Name   Age          SSN  \
#  0     0x160a   CUS_0xd40  September    Aaron Maashoh    23  821-00-0265
#  1     0x160b   CUS_0xd40    October    Aaron Maashoh    24  821-00-0265
#  2     0x160c   CUS_0xd40   November    Aaron Maashoh    24  821-00-0265
#  3     0x160d   CUS_0xd40   December    Aaron Maashoh   24_  821-00-0265
#  4     0x1616  CUS_0x21b1  September  Rick Rothackerj    28  004-07-5839
#  ...      ...         ...        ...              ...   ...          ...
#  5995  0x5c45  CUS_0x8a8c   December    Karen Jacobsu    32  520-12-7956
#  5996  0x5c4e  CUS_0x122f  September         Donovang    24  179-85-5358
#  5997  0x5c4f  CUS_0x122f    October         Donovang    24  179-85-5358
#  5998  0x5c50  CUS_0x122f   November              NaN    24  179-85-5358
#  5999  0x5c51  CUS_0x122f   December         Donovang  5488  179-85-5358
#
#           Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
#  0         Scientist      19114.12            1824.843333                  3
#  1         Scientist      19114.12            1824.843333                  3
#  2         Scientist      19114.12            1824.843333                  3
#  3         Scientist      19114.12                    NaN                  3
#  4           _______      34847.84            3037.986667                  2
#  ...             ...           ...                    ...                ...
#  5995         Doctor      14219.02                    NaN                 10
#  5996  Media_Manager      18231.52                    NaN                  6
#  5997  Media_Manager      18231.52            1448.293333                  6
#  5998  Media_Manager      18231.52            1448.293333                  6
#  5999  Media_Manager      18231.52            1448.293333                  6
#
#        ...  Credit_Mix  Outstanding_Debt Credit_Utilization_Ratio  \
#  0     ...        Good            809.98                35.030402
#  1     ...        Good            809.98                33.053114
#  2     ...        Good            809.98                33.811894
#  3     ...        Good            809.98                32.430559
#  4     ...        Good            605.03                25.926822
#  ...   ...         ...               ...                      ...
#  5995  ...         Bad            3628.5                27.975839
#  5996  ...           _           1358.96                26.281263
#  5997  ...         Bad           1358.96                33.889744
#  5998  ...           _           1358.96                34.718260
#  5999  ...         Bad           1358.96                36.250306
#
#            Credit_History_Age  Payment_of_Min_Amount Total_EMI_per_month  \
#  0      22 Years and 9 Months                     No           49.574949
#  1     22 Years and 10 Months                     No           49.574949
#  2                        NaN                     No           49.574949
#  3      23 Years and 0 Months                     No           49.574949
#  4      27 Years and 3 Months                     No           18.816215
#  ...                      ...                    ...                 ...
#  5995    3 Years and 8 Months                     NM           76.486008
#  5996   15 Years and 6 Months                    Yes           86.608647
#  5997   15 Years and 7 Months                    Yes           86.608647
#  5998   15 Years and 8 Months                    Yes           86.608647
#  5999   15 Years and 9 Months                    Yes           86.608647
#
#       Amount_invested_monthly                 Payment_Behaviour  \
#  0         236.64268203272135    Low_spent_Small_value_payments
#  1         21.465380264657146  High_spent_Medium_value_payments
#  2         148.23393788500925   Low_spent_Medium_value_payments
#  3          39.08251089460281  High_spent_Medium_value_payments
#  4         39.684018417945296   High_spent_Large_value_payments
#  ...                      ...                               ...
#  5995        79.3613953137231   Low_spent_Medium_value_payments
#  5996      154.47017169345767    Low_spent_Small_value_payments
#  5997      42.358067683971626  High_spent_Medium_value_payments
#  5998      172.55816847802882    Low_spent_Small_value_payments
#  5999      13.107727973689306   High_spent_Large_value_payments
#
#       Monthly_Balance Credit_Score
#  0         186.266702          NaN
#  1         361.444004          NaN
#  2         264.675446          NaN
#  3         343.826873          NaN
#  4         485.298434          NaN
#  ...              ...          ...
#  5995      236.844430          NaN
#  5996      193.750515          NaN
#  5997      265.862619          NaN
#  5998      175.662518          NaN
#  5999      285.112958          NaN
#
#  [6000 rows x 28 columns]]

# %%
# Combine all dataframes into a single one
if file_dataframes:
    combined_df = pd.concat(file_dataframes, ignore_index=True)

# %%
combined_df
# Out:
#              ID Customer_ID      Month            Name   Age          SSN  \
# 0       0x23cca  CUS_0x8b6d    January  Scott Haggettl    23  796-69-6764
# 1       0x23ccb  CUS_0x8b6d   February  Scott Haggettl    23    #F%$D@*&8
# 2       0x23ccc  CUS_0x8b6d      March  Scott Haggettl    23  796-69-6764
# 3       0x23ccd  CUS_0x8b6d      April  Scott Haggettl  5615  796-69-6764
# 4       0x23cce  CUS_0x8b6d        May  Scott Haggettl    23  796-69-6764
# ...         ...         ...        ...             ...   ...          ...
# 149995   0x5c45  CUS_0x8a8c   December   Karen Jacobsu    32  520-12-7956
# 149996   0x5c4e  CUS_0x122f  September        Donovang    24  179-85-5358
# 149997   0x5c4f  CUS_0x122f    October        Donovang    24  179-85-5358
# 149998   0x5c50  CUS_0x122f   November             NaN    24  179-85-5358
# 149999   0x5c51  CUS_0x122f   December        Donovang  5488  179-85-5358
#
#            Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0            Musician      102594.9            8391.575000                  3
# 1            Musician     102594.9_            8391.575000                  3
# 2            Musician      102594.9            8391.575000                  3
# 3             _______      102594.9            8391.575000                  3
# 4            Musician      102594.9                    NaN                  3
# ...               ...           ...                    ...                ...
# 149995         Doctor      14219.02                    NaN                 10
# 149996  Media_Manager      18231.52                    NaN                  6
# 149997  Media_Manager      18231.52            1448.293333                  6
# 149998  Media_Manager      18231.52            1448.293333                  6
# 149999  Media_Manager      18231.52            1448.293333                  6
#
#         ...  Credit_Mix  Outstanding_Debt Credit_Utilization_Ratio  \
# 0       ...    Standard            416.11                30.601881
# 1       ...           _            416.11                43.528168
# 2       ...    Standard            416.11                37.487060
# 3       ...    Standard            416.11                35.125945
# 4       ...    Standard            416.11                38.284492
# ...     ...         ...               ...                      ...
# 149995  ...         Bad            3628.5                27.975839
# 149996  ...           _           1358.96                26.281263
# 149997  ...         Bad           1358.96                33.889744
# 149998  ...           _           1358.96                34.718260
# 149999  ...         Bad           1358.96                36.250306
#
#             Credit_History_Age  Payment_of_Min_Amount Total_EMI_per_month  \
# 0                          NaN                     No            0.000000
# 1        18 Years and 9 Months                     No            0.000000
# 2       18 Years and 10 Months                     NM            0.000000
# 3       18 Years and 11 Months                     No            0.000000
# 4        19 Years and 0 Months                     No            0.000000
# ...                        ...                    ...                 ...
# 149995    3 Years and 8 Months                     NM           76.486008
# 149996   15 Years and 6 Months                    Yes           86.608647
# 149997   15 Years and 7 Months                    Yes           86.608647
# 149998   15 Years and 8 Months                    Yes           86.608647
# 149999   15 Years and 9 Months                    Yes           86.608647
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 0            653.9822978912564    Low_spent_Large_value_payments
# 1           186.52023659780826   High_spent_Large_value_payments
# 2            250.4766071514879  High_spent_Medium_value_payments
# 3           143.98347272538896   High_spent_Large_value_payments
# 4            651.6394489063042   Low_spent_Medium_value_payments
# ...                        ...                               ...
# 149995        79.3613953137231   Low_spent_Medium_value_payments
# 149996      154.47017169345767    Low_spent_Small_value_payments
# 149997      42.358067683971626  High_spent_Medium_value_payments
# 149998      172.55816847802882    Low_spent_Small_value_payments
# 149999      13.107727973689306   High_spent_Large_value_payments
#
#        Monthly_Balance Credit_Score
# 0           455.175202     Standard
# 1           892.637263     Standard
# 2           838.680893     Standard
# 3           935.174027     Standard
# 4           467.518051     Standard
# ...                ...          ...
# 149995       236.84443          NaN
# 149996      193.750515          NaN
# 149997      265.862619          NaN
# 149998      175.662518          NaN
# 149999      285.112958          NaN
#
# [150000 rows x 28 columns]
